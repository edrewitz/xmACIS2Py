# %%
import xmacis2py.analysis_tools.analysis as analysis
from xmacis2py.data_access.station_data import(
    get_single_station_acis_data,
    get_multi_station_acis_data,
    get_single_station_climate_normals
)

# %%
df = get_single_station_acis_data('kjfk',
                                   start_date='1950-01-01',
                                   end_date='2026-04-21',
                                    to_csv=True,
                                    return_pandas_df=False)
# Out:
# KJFK Data Saved: XMACIS2 DATA/KJFK.csv

# %%
df

# %%
analysis.calculate_daily_normals('kjfk',
                                 input_path=f"XMACIS2 DATA/KJFK.csv",
                                to_csv=True,
                                return_pandas_df=False)
