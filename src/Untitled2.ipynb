# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

from io import StringIO

# %%
params = {
    "state":"ca",
    "sdate":"20400701",
    "edate":"20400731",
    "grid":"6",
    "output":"json",
    "elems":[{"name":"pcpn","smry":"sum","smry_only":1}],
    "image":{
        "proj":"lcc",
        "overlays":"state",
        "interp":"cspline",
        "cmap":"rainbow",
        "width":350
        #"levels":levels
    }
}

# %%
response = requests.post("https://data.rcc-acis.org/", data={'params': json.dumps(params)}, headers={"Accept":"application/json"})
