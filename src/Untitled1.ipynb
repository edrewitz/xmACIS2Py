# %%
from xmacis2py.data_access.station_data import(
    get_single_station_acis_data,
    get_multi_station_acis_data,
    get_single_station_climate_normals,
    get_multi_station_climate_normals,
    get_single_station_departures,
    get_multi_station_departures
)

# %%
dfs = get_multi_station_departures(['kont', 'klax'], start_date='2020-03-01', end_date='2026-03-31', interval='daily', to_csv=True)
# Out:
# KONT Data Saved: XMACIS2 DEPARTURES/DAILY/KONT.csv
# KLAX Data Saved: XMACIS2 DEPARTURES/DAILY/KLAX.csv

# %%
dfs[1]
# Out:
#            Date  Maximum Temperature Departure  Minimum Temperature Departure  \
# 0    2020-03-01                           -2.0                              2
# 1    2020-03-02                           10.0                              0
# 2    2020-03-03                           14.0                              8
# 3    2020-03-04                            7.0                              4
# 4    2020-03-05                            1.0                              4
# ...         ...                            ...                            ...
# 2217 2026-03-27                            4.0                              6
# 2218 2026-03-28                            1.0                              5
# 2219 2026-03-29                            6.0                              4
# 2220 2026-03-30                            3.0                              3
# 2221 2026-03-31                            2.0                              9
#
#       Average Temperature Departure  Heating Degree Days Departure  \
# 0                              -0.3                            0.0
# 1                               5.1                           -6.0
# 2                              11.1                           -7.0
# 3                               5.5                           -6.0
# 4                               3.0                           -4.0
# ...                             ...                            ...
# 2217                            5.2                           -6.0
# 2218                            3.2                           -3.0
# 2219                            5.1                           -5.0
# 2220                            3.1                           -3.0
# 2221                            5.5                           -5.0
#
#       Cooling Degree Days Departure  Growing Degree Days Departure  \
# 0                              -0.0                           -0.0
# 1                              -0.0                            6.0
# 2                               5.0                           12.0
# 3                              -0.0                            6.0
# 4                              -0.0                            4.0
# ...                             ...                            ...
# 2217                           -0.0                            5.0
# 2218                           -0.0                            3.0
# 2219                           -0.0                            5.0
# 2220                           -0.0                            3.0
# 2221                            1.0                            6.0
#
#       Precipitation Departure  Snowfall Departure
# 0                       -0.08                 NaN
# 1                       -0.08                 NaN
# 2                       -0.08                 NaN
# 3                       -0.08                 NaN
# 4                       -0.07                 NaN
# ...                       ...                 ...
# 2217                    -0.04                 NaN
# 2218                    -0.04                 NaN
# 2219                    -0.04                 NaN
# 2220                    -0.04                 NaN
# 2221                     0.03                 NaN
#
# [2222 rows x 9 columns]
